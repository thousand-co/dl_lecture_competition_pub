# %%
import torch
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mne

data_dir='./data_spl'
X = torch.load(os.path.join(data_dir, f"val_X_0.pt"))
y = torch.load(os.path.join(data_dir, f"val_y_0.pt"))

# %%
X.shape
# Out:
# torch.Size([4108, 271, 281])

# %%
y.shape
# Out:
# torch.Size([4108])

# %%
plt.hist(X[0].flatten(), bins=50)
# Out:
# (array([2.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00, 3.0000e+00,
#         4.0000e+00, 3.0000e+00, 9.0000e+00, 1.8000e+01, 2.4000e+01,
#         1.9000e+01, 3.6000e+01, 4.4000e+01, 5.3000e+01, 8.5000e+01,
#         1.2100e+02, 1.8600e+02, 2.8800e+02, 3.7500e+02, 6.1900e+02,
#         7.7800e+02, 1.3220e+03, 1.9930e+03, 3.1240e+03, 5.2480e+03,
#         8.5820e+03, 1.2361e+04, 1.2839e+04, 1.0188e+04, 7.2910e+03,
#         4.5480e+03, 2.4280e+03, 1.3130e+03, 7.5500e+02, 4.2200e+02,
#         3.1400e+02, 2.0300e+02, 1.8600e+02, 1.0300e+02, 8.3000e+01,
#         6.0000e+01, 3.4000e+01, 3.0000e+01, 2.4000e+01, 1.8000e+01,
#         5.0000e+00, 3.0000e+00, 2.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([-16.45953178, -15.8599577 , -15.26038361, -14.66080952,
#         -14.06123543, -13.46166229, -12.8620882 , -12.26251411,
#         -11.66294003, -11.06336594, -10.46379185,  -9.86421776,
#          -9.26464367,  -8.66506958,  -8.06549549,  -7.46592188,
#          -6.86634779,  -6.2667737 ,  -5.66720009,  -5.067626  ,
#          -4.46805191,  -3.86847782,  -3.26890397,  -2.66932988,
#          -2.06975603,  -1.47018194,  -0.87060797,  -0.27103394,
#           0.32854003,   0.92811406,   1.52768803,   2.12726212,
#           2.72683597,   3.32641006,   3.92598391,   4.52555799,
#           5.12513208,   5.72470617,   6.32427979,   6.92385387,
#           7.52342796,   8.12300205,   8.72257614,   9.32215023,
#           9.92172432,  10.52129745,  11.12087154,  11.72044563,
#          12.32001972,  12.91959381,  13.5191679 ]),
#  <BarContainer object of 50 artists>)

# %%
X[5].view(-1).shape
# Out:
# torch.Size([76151])

# %%
import torchvision.transforms as tf
from torchvision.transforms import ToTensor

transform=ToTensor()
newdat=transform(X[5].numpy())
plt.hist(newdat.flatten(), bins=50)
# Out:
# (array([1.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00, 1.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 3.0000e+00,
#         3.0000e+00, 4.0000e+00, 7.0000e+00, 1.1000e+01, 1.3000e+01,
#         2.2000e+01, 2.5000e+01, 4.0000e+01, 6.2000e+01, 1.0700e+02,
#         1.4600e+02, 2.1300e+02, 3.0600e+02, 4.2700e+02, 6.9200e+02,
#         1.0690e+03, 1.7470e+03, 2.7880e+03, 4.5360e+03, 8.5170e+03,
#         1.3240e+04, 1.5678e+04, 1.2447e+04, 7.2850e+03, 3.5540e+03,
#         1.7140e+03, 7.4400e+02, 3.6500e+02, 1.8700e+02, 8.6000e+01,
#         3.7000e+01, 3.0000e+01, 1.5000e+01, 1.1000e+01, 4.0000e+00,
#         3.0000e+00, 1.0000e+00, 2.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([-2.65200939e+01, -2.56637974e+01, -2.48075027e+01, -2.39512062e+01,
#         -2.30949116e+01, -2.22386150e+01, -2.13823204e+01, -2.05260239e+01,
#         -1.96697292e+01, -1.88134327e+01, -1.79571362e+01, -1.71008415e+01,
#         -1.62445450e+01, -1.53882494e+01, -1.45319538e+01, -1.36756582e+01,
#         -1.28193626e+01, -1.19630671e+01, -1.11067715e+01, -1.02504759e+01,
#         -9.39418030e+00, -8.53788376e+00, -7.68158865e+00, -6.82529259e+00,
#         -5.96899700e+00, -5.11270142e+00, -4.25640583e+00, -3.40011001e+00,
#         -2.54381442e+00, -1.68751860e+00, -8.31222892e-01,  2.50727851e-02,
#          8.81368458e-01,  1.73766422e+00,  2.59395981e+00,  3.45025563e+00,
#          4.30655146e+00,  5.16284704e+00,  6.01914263e+00,  6.87543821e+00,
#          7.73173428e+00,  8.58802986e+00,  9.44432545e+00,  1.03006210e+01,
#          1.11569166e+01,  1.20132122e+01,  1.28695087e+01,  1.37258043e+01,
#          1.45820999e+01,  1.54383955e+01,  1.62946911e+01]),
#  <BarContainer object of 50 artists>)

# %%
from torch.nn import BatchNorm1d
batchnorm = BatchNorm1d(281)
#m = BatchNorm1d(281, affine=False)
output = batchnorm(X[5])
output.shape
# Out:
# torch.Size([271, 281])

# %%
plt.hist(output.detach().numpy().flatten(), bins=50)
# Out:
# (array([1.000e+00, 6.000e+00, 9.000e+00, 4.000e+00, 1.100e+01, 1.800e+01,
#         1.900e+01, 1.900e+01, 2.500e+01, 3.000e+01, 6.000e+01, 8.800e+01,
#         1.040e+02, 1.340e+02, 1.670e+02, 2.380e+02, 3.170e+02, 4.590e+02,
#         7.210e+02, 1.036e+03, 1.577e+03, 2.204e+03, 3.035e+03, 4.051e+03,
#         5.337e+03, 7.332e+03, 9.013e+03, 9.649e+03, 8.950e+03, 7.389e+03,
#         5.553e+03, 3.609e+03, 2.190e+03, 1.259e+03, 6.810e+02, 3.690e+02,
#         1.850e+02, 9.500e+01, 6.100e+01, 3.400e+01, 2.800e+01, 2.400e+01,
#         1.600e+01, 1.600e+01, 1.000e+01, 6.000e+00, 5.000e+00, 4.000e+00,
#         1.000e+00, 2.000e+00]),
#  array([-6.95161343, -6.69321108, -6.43480873, -6.17640638, -5.91800404,
#         -5.65960169, -5.40119934, -5.14279699, -4.88439465, -4.6259923 ,
#         -4.36758995, -4.1091876 , -3.85078549, -3.59238315, -3.3339808 ,
#         -3.07557845, -2.8171761 , -2.55877376, -2.30037141, -2.0419693 ,
#         -1.78356683, -1.52516448, -1.26676226, -1.00835991, -0.74995756,
#         -0.49155521, -0.23315288,  0.02524944,  0.28365177,  0.54205412,
#          0.8004564 ,  1.05885875,  1.3172611 ,  1.57566345,  1.83406579,
#          2.09246802,  2.35087037,  2.60927272,  2.86767507,  3.12607741,
#          3.38447976,  3.64288211,  3.90128446,  4.15968657,  4.41808891,
#          4.67649126,  4.93489361,  5.19329596,  5.4516983 ,  5.71010065,
#          5.968503  ]),
#  <BarContainer object of 50 artists>)

# %%
from torch.nn.functional import normalize

output = normalize(X[5])
output.shape
# Out:
# torch.Size([271, 281])

# %%
plt.hist(output.detach().numpy().flatten(), bins=50)
# Out:
# (array([3.000e+00, 6.000e+00, 7.000e+00, 1.300e+01, 2.100e+01, 2.600e+01,
#         5.700e+01, 5.900e+01, 7.500e+01, 1.170e+02, 1.630e+02, 2.680e+02,
#         3.250e+02, 4.380e+02, 5.460e+02, 6.900e+02, 9.580e+02, 1.312e+03,
#         1.651e+03, 2.080e+03, 2.444e+03, 2.700e+03, 3.044e+03, 3.554e+03,
#         3.797e+03, 3.940e+03, 4.383e+03, 4.459e+03, 4.674e+03, 4.664e+03,
#         4.474e+03, 4.593e+03, 4.264e+03, 3.983e+03, 3.378e+03, 2.669e+03,
#         1.929e+03, 1.396e+03, 9.690e+02, 6.330e+02, 4.820e+02, 3.370e+02,
#         2.590e+02, 1.410e+02, 9.000e+01, 5.000e+01, 1.700e+01, 1.000e+01,
#         2.000e+00, 1.000e+00]),
#  array([-0.25512221, -0.24574228, -0.23636232, -0.22698238, -0.21760245,
#         -0.20822249, -0.19884256, -0.18946262, -0.18008266, -0.17070273,
#         -0.16132279, -0.15194283, -0.1425629 , -0.13318296, -0.123803  ,
#         -0.11442307, -0.10504312, -0.09566317, -0.08628324, -0.07690329,
#         -0.06752335, -0.0581434 , -0.04876346, -0.03938352, -0.03000358,
#         -0.02062363, -0.01124369, -0.00186375,  0.0075162 ,  0.01689614,
#          0.02627609,  0.03565603,  0.04503597,  0.05441592,  0.06379586,
#          0.0731758 ,  0.08255574,  0.09193569,  0.10131563,  0.11069558,
#          0.12007552,  0.12945546,  0.1388354 ,  0.14821535,  0.15759529,
#          0.16697523,  0.17635518,  0.18573512,  0.19511506,  0.20449501,
#          0.21387495]),
#  <BarContainer object of 50 artists>)

# %%
from torchvision.transforms import Normalize
norm=Normalize(0.5, 0.5)
data=norm(X[5].unsqueeze(0))

# %%
plt.hist(output.detach().numpy().flatten(), bins=50)
# Out:
# (array([3.000e+00, 6.000e+00, 7.000e+00, 1.300e+01, 2.100e+01, 2.600e+01,
#         5.700e+01, 5.900e+01, 7.500e+01, 1.170e+02, 1.630e+02, 2.680e+02,
#         3.250e+02, 4.380e+02, 5.460e+02, 6.900e+02, 9.580e+02, 1.312e+03,
#         1.651e+03, 2.080e+03, 2.444e+03, 2.700e+03, 3.044e+03, 3.554e+03,
#         3.797e+03, 3.940e+03, 4.383e+03, 4.459e+03, 4.674e+03, 4.664e+03,
#         4.474e+03, 4.593e+03, 4.264e+03, 3.983e+03, 3.378e+03, 2.669e+03,
#         1.929e+03, 1.396e+03, 9.690e+02, 6.330e+02, 4.820e+02, 3.370e+02,
#         2.590e+02, 1.410e+02, 9.000e+01, 5.000e+01, 1.700e+01, 1.000e+01,
#         2.000e+00, 1.000e+00]),
#  array([-0.25512221, -0.24574228, -0.23636232, -0.22698238, -0.21760245,
#         -0.20822249, -0.19884256, -0.18946262, -0.18008266, -0.17070273,
#         -0.16132279, -0.15194283, -0.1425629 , -0.13318296, -0.123803  ,
#         -0.11442307, -0.10504312, -0.09566317, -0.08628324, -0.07690329,
#         -0.06752335, -0.0581434 , -0.04876346, -0.03938352, -0.03000358,
#         -0.02062363, -0.01124369, -0.00186375,  0.0075162 ,  0.01689614,
#          0.02627609,  0.03565603,  0.04503597,  0.05441592,  0.06379586,
#          0.0731758 ,  0.08255574,  0.09193569,  0.10131563,  0.11069558,
#          0.12007552,  0.12945546,  0.1388354 ,  0.14821535,  0.15759529,
#          0.16697523,  0.17635518,  0.18573512,  0.19511506,  0.20449501,
#          0.21387495]),
#  <BarContainer object of 50 artists>)

# %%
from torchaudio.transforms import Spectrogram, MelSpectrogram
from torch.nn import functional as F
from torch import t
import numpy as np
import albumentations as A

melspectgram = MelSpectrogram(sample_rate=1200)

data=melspectgram(t(X[5]))
data1=t(data[:,:,0])
data2=t(data[:,:,1])
data=torch.cat((data1, data2), 0)
data=F.adaptive_avg_pool1d(data, 512)
data=F.adaptive_avg_pool1d(t(data), 512)
data=t(data)
data=F.normalize(data)
print("Shape of spectrogram: {}".format(data.size()))
plt.figure()
plt.imshow(data, cmap='RdBu_r')
# Out:
# Shape of spectrogram: torch.Size([512, 512])

# %%
plt.hist(data.flatten(), bins=50)
# Out:
# (array([5.7518e+04, 4.5254e+04, 3.4280e+04, 2.6852e+04, 2.1266e+04,
#         1.6996e+04, 1.2580e+04, 1.0046e+04, 7.6580e+03, 6.3380e+03,
#         5.0800e+03, 3.8480e+03, 2.9720e+03, 2.4280e+03, 1.8220e+03,
#         1.4280e+03, 1.1680e+03, 8.5600e+02, 7.1400e+02, 5.3800e+02,
#         4.2400e+02, 3.9000e+02, 3.0600e+02, 2.0400e+02, 1.9000e+02,
#         1.3000e+02, 1.1200e+02, 1.0200e+02, 8.6000e+01, 7.4000e+01,
#         6.2000e+01, 5.2000e+01, 3.4000e+01, 5.0000e+01, 4.4000e+01,
#         4.2000e+01, 2.6000e+01, 3.2000e+01, 3.2000e+01, 2.2000e+01,
#         1.4000e+01, 1.8000e+01, 1.4000e+01, 1.0000e+01, 6.0000e+00,
#         2.0000e+00, 0.0000e+00, 1.2000e+01, 8.0000e+00, 4.0000e+00]),
#  array([5.64632228e-06, 7.43137673e-03, 1.48571078e-02, 2.22828388e-02,
#         2.97085680e-02, 3.71343009e-02, 4.45600301e-02, 5.19857593e-02,
#         5.94114922e-02, 6.68372214e-02, 7.42629543e-02, 8.16886798e-02,
#         8.91144127e-02, 9.65401456e-02, 1.03965871e-01, 1.11391604e-01,
#         1.18817337e-01, 1.26243070e-01, 1.33668795e-01, 1.41094521e-01,
#         1.48520261e-01, 1.55945987e-01, 1.63371712e-01, 1.70797452e-01,
#         1.78223178e-01, 1.85648903e-01, 1.93074644e-01, 2.00500369e-01,
#         2.07926095e-01, 2.15351835e-01, 2.22777560e-01, 2.30203301e-01,
#         2.37629026e-01, 2.45054752e-01, 2.52480477e-01, 2.59906203e-01,
#         2.67331958e-01, 2.74757683e-01, 2.82183409e-01, 2.89609134e-01,
#         2.97034860e-01, 3.04460585e-01, 3.11886340e-01, 3.19312066e-01,
#         3.26737791e-01, 3.34163517e-01, 3.41589242e-01, 3.49014968e-01,
#         3.56440723e-01, 3.63866448e-01, 3.71292174e-01]),
#  <BarContainer object of 50 artists>)

# %%
data=melspectgram(t(X[5]))
data1=t(data.log2()[:,:,0])
data2=t(data.log2()[:,:,1])
data=torch.cat((data1, data2), 0)
data=F.adaptive_avg_pool1d(data, 512)
data=F.adaptive_avg_pool1d(t(data), 512)
data=t(data)
data=F.normalize(data)
print("Shape of spectrogram: {}".format(data.size()))
plt.figure()
plt.imshow(data, cmap='RdBu_r')
# Out:
# Shape of spectrogram: torch.Size([512, 512])

# %%
plt.hist(data.flatten(), bins=50)
# Out:
# (array([4.0000e+00, 2.0000e+00, 0.0000e+00, 4.0000e+00, 2.0000e+00,
#         1.0000e+01, 1.0000e+01, 2.0000e+01, 2.2000e+01, 4.6000e+01,
#         6.4000e+01, 6.6000e+01, 7.2000e+01, 1.5400e+02, 2.2400e+02,
#         2.6200e+02, 4.4800e+02, 5.6600e+02, 8.5200e+02, 1.1660e+03,
#         1.6040e+03, 2.1300e+03, 2.8620e+03, 3.7140e+03, 4.5580e+03,
#         5.9260e+03, 7.3180e+03, 9.2860e+03, 1.1386e+04, 1.3672e+04,
#         1.6510e+04, 1.9062e+04, 2.1420e+04, 2.3724e+04, 2.5758e+04,
#         2.3106e+04, 1.9522e+04, 1.5548e+04, 1.1408e+04, 7.9560e+03,
#         5.0260e+03, 2.9420e+03, 1.7840e+03, 9.1200e+02, 4.5200e+02,
#         2.5800e+02, 1.5800e+02, 8.2000e+01, 4.4000e+01, 2.2000e+01]),
#  array([-0.01748392, -0.01562841, -0.0137729 , -0.0119174 , -0.01006189,
#         -0.00820638, -0.00635087, -0.00449537, -0.00263986, -0.00078435,
#          0.00107115,  0.00292666,  0.00478217,  0.00663768,  0.00849318,
#          0.01034869,  0.0122042 ,  0.0140597 ,  0.01591521,  0.01777072,
#          0.01962622,  0.02148173,  0.02333724,  0.02519275,  0.02704825,
#          0.02890376,  0.03075927,  0.03261478,  0.03447028,  0.03632579,
#          0.0381813 ,  0.0400368 ,  0.04189231,  0.04374782,  0.04560332,
#          0.04745883,  0.04931434,  0.05116985,  0.05302535,  0.05488086,
#          0.05673637,  0.05859188,  0.06044738,  0.06230289,  0.06415839,
#          0.0660139 ,  0.06786941,  0.06972492,  0.07158042,  0.07343593,
#          0.07529144]),
#  <BarContainer object of 50 artists>)

# %%
spectgram = Spectrogram()

data=spectgram(t(X[5]))
data1=t(data[:,:,0])
data2=t(data[:,:,1])
data=torch.cat((data1, data2), 0)
data=F.adaptive_avg_pool1d(data, 512)
data=F.adaptive_avg_pool1d(t(data), 512)
data=t(data)
data=F.normalize(data)
print("Shape of spectrogram: {}".format(data.size()))
plt.figure()
plt.imshow(data, cmap='RdBu_r')
# Out:
# Shape of spectrogram: torch.Size([512, 512])

# %%
plt.hist(data.flatten(), bins=50)
# Out:
# (array([7.1142e+04, 4.4853e+04, 3.3088e+04, 2.5363e+04, 1.9557e+04,
#         1.5061e+04, 1.1651e+04, 9.1230e+03, 7.1390e+03, 5.4980e+03,
#         4.4060e+03, 3.3260e+03, 2.6330e+03, 1.9450e+03, 1.5530e+03,
#         1.1860e+03, 8.7400e+02, 7.0900e+02, 6.0300e+02, 4.8500e+02,
#         3.5700e+02, 3.1400e+02, 2.3500e+02, 1.7000e+02, 1.3000e+02,
#         1.0500e+02, 1.0700e+02, 7.7000e+01, 6.7000e+01, 5.6000e+01,
#         4.3000e+01, 5.5000e+01, 3.3000e+01, 3.1000e+01, 2.7000e+01,
#         2.3000e+01, 1.8000e+01, 2.0000e+01, 1.5000e+01, 1.8000e+01,
#         1.0000e+01, 5.0000e+00, 6.0000e+00, 1.0000e+01, 7.0000e+00,
#         2.0000e+00, 3.0000e+00, 2.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([1.91200805e-11, 8.02978780e-03, 1.60595756e-02, 2.40893643e-02,
#         3.21191512e-02, 4.01489399e-02, 4.81787287e-02, 5.62085174e-02,
#         6.42383024e-02, 7.22680911e-02, 8.02978799e-02, 8.83276686e-02,
#         9.63574573e-02, 1.04387246e-01, 1.12417035e-01, 1.20446824e-01,
#         1.28476605e-01, 1.36506394e-01, 1.44536182e-01, 1.52565971e-01,
#         1.60595760e-01, 1.68625548e-01, 1.76655337e-01, 1.84685126e-01,
#         1.92714915e-01, 2.00744703e-01, 2.08774492e-01, 2.16804281e-01,
#         2.24834070e-01, 2.32863858e-01, 2.40893647e-01, 2.48923436e-01,
#         2.56953210e-01, 2.64982998e-01, 2.73012787e-01, 2.81042576e-01,
#         2.89072365e-01, 2.97102153e-01, 3.05131942e-01, 3.13161731e-01,
#         3.21191519e-01, 3.29221308e-01, 3.37251097e-01, 3.45280886e-01,
#         3.53310674e-01, 3.61340463e-01, 3.69370252e-01, 3.77400041e-01,
#         3.85429829e-01, 3.93459618e-01, 4.01489407e-01]),
#  <BarContainer object of 50 artists>)

# %%
data=X[5]
data=F.adaptive_avg_pool1d(data, 512)
data=F.adaptive_avg_pool1d(t(data), 512)
data=t(data)
data=F.normalize(data)
print("Shape of spectrogram: {}".format(data.size()))
plt.figure()
plt.imshow(data, cmap='RdBu_r')
# Out:
# Shape of spectrogram: torch.Size([512, 512])

# %%
plt.hist(data.flatten(), bins=50)
# Out:
# (array([2.0000e+00, 2.0000e+00, 4.0000e+00, 1.7000e+01, 2.7000e+01,
#         4.5000e+01, 6.0000e+01, 1.1000e+02, 1.7400e+02, 2.1600e+02,
#         3.4400e+02, 4.3500e+02, 6.3000e+02, 9.6500e+02, 1.2650e+03,
#         1.7410e+03, 2.1510e+03, 2.8770e+03, 3.9990e+03, 5.3030e+03,
#         6.7170e+03, 8.2300e+03, 9.3070e+03, 1.0493e+04, 1.1897e+04,
#         1.3292e+04, 1.4125e+04, 1.5178e+04, 1.5785e+04, 1.6501e+04,
#         1.6591e+04, 1.6179e+04, 1.5999e+04, 1.5575e+04, 1.4339e+04,
#         1.2150e+04, 9.0720e+03, 6.4270e+03, 4.5240e+03, 3.0420e+03,
#         2.1150e+03, 1.5440e+03, 1.0850e+03, 7.8000e+02, 4.2500e+02,
#         2.6000e+02, 9.9000e+01, 3.7000e+01, 6.0000e+00, 3.0000e+00]),
#  array([-0.20505112, -0.1978351 , -0.19061908, -0.18340306, -0.17618704,
#         -0.168971  , -0.16175498, -0.15453896, -0.14732294, -0.14010692,
#         -0.1328909 , -0.12567487, -0.11845885, -0.11124282, -0.1040268 ,
#         -0.09681078, -0.08959476, -0.08237874, -0.07516271, -0.06794669,
#         -0.06073067, -0.05351464, -0.04629862, -0.0390826 , -0.03186657,
#         -0.02465055, -0.01743453, -0.01021851, -0.00300248,  0.00421354,
#          0.01142956,  0.01864559,  0.02586161,  0.03307763,  0.04029366,
#          0.04750968,  0.0547257 ,  0.06194172,  0.06915775,  0.07637377,
#          0.08358979,  0.09080581,  0.09802184,  0.10523786,  0.11245389,
#          0.11966991,  0.12688594,  0.13410196,  0.14131798,  0.148534  ,
#          0.15575002]),
#  <BarContainer object of 50 artists>)

# %%
from scipy.signal import butter, lfilter

def quantize_data(data, classes):
    mu_x = mu_law_encoding(data, classes)
    return mu_x  # quantized


def mu_law_encoding(data, mu):
    mu_x = np.sign(data) * np.log(1 + mu * np.abs(data)) / np.log(mu + 1)
    return mu_x


def mu_law_expansion(data, mu):
    s = np.sign(data) * (np.exp(np.abs(data) * np.log(mu + 1)) - 1) / mu
    return s


def butter_bandpass(lowcut, highcut, fs, order=5):
    return butter(order, [lowcut, highcut], fs=fs, btype="band")


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y


#def butter_lowpass_filter(data, cutoff_freq=20, sampling_rate=CFG.sampling_rate, order=4):
#    nyquist = 0.5 * sampling_rate
#    normal_cutoff = cutoff_freq / nyquist
#    b, a = butter(order, normal_cutoff, btype="low", analog=False)
#    filtered_data = lfilter(b, a, data, axis=0)
#    return filtered_data


#def denoise_filter(x):
#    y = butter_bandpass_filter(x, CFG.lowcut, CFG.highcut, CFG.sampling_rate, order=6)
#    y = (y + np.roll(y, -1) + np.roll(y, -2) + np.roll(y, -3)) / 4
#    y = y[0:-1:4]
#    return y

# %%
num=5
data0=t(torch.tensor(butter_bandpass_filter(t(X[num]), 1, 50, 1200)))
data1=t(torch.tensor(butter_bandpass_filter(t(X[num]), 50, 100, 1200)))
data2=t(torch.tensor(butter_bandpass_filter(t(X[num]), 100, 200, 1200)))
data3=t(torch.tensor(butter_bandpass_filter(t(X[num]), 200, 400, 1200)))
data0.shape
# Out:
# torch.Size([271, 281])

# %%
data=torch.cat((data0, data1), 0)
data=F.adaptive_avg_pool1d(data, 512)
data=F.adaptive_avg_pool1d(t(data), 512)
data=t(data)
data=F.normalize(data)
print("Shape of spectrogram: {}".format(data.size()))
plt.figure()
plt.imshow(data, cmap='RdBu_r')
# Out:
# Shape of spectrogram: torch.Size([512, 512])

# %%
plt.hist(data.flatten(), bins=50)
# Out:
# (array([6.0000e+00, 1.0000e+00, 7.0000e+00, 1.0000e+01, 1.7000e+01,
#         2.3000e+01, 7.0000e+01, 8.1000e+01, 1.4600e+02, 2.3500e+02,
#         3.0600e+02, 5.0200e+02, 7.7300e+02, 1.2170e+03, 1.7040e+03,
#         2.4760e+03, 3.6050e+03, 5.3470e+03, 7.1050e+03, 8.5890e+03,
#         1.0167e+04, 1.2544e+04, 1.4615e+04, 1.5547e+04, 1.6850e+04,
#         1.8068e+04, 1.8437e+04, 1.7592e+04, 1.6691e+04, 1.6311e+04,
#         1.5505e+04, 1.4213e+04, 1.1914e+04, 9.8390e+03, 7.2990e+03,
#         5.1030e+03, 3.3760e+03, 2.1030e+03, 1.3980e+03, 8.0400e+02,
#         5.3300e+02, 3.4500e+02, 2.4000e+02, 1.4200e+02, 1.1700e+02,
#         9.5000e+01, 4.4000e+01, 1.6000e+01, 1.0000e+01, 6.0000e+00]),
#  array([-0.21093092, -0.2029467 , -0.19496249, -0.18697827, -0.17899406,
#         -0.17100984, -0.16302562, -0.15504141, -0.14705719, -0.13907298,
#         -0.13108876, -0.12310455, -0.11512033, -0.10713612, -0.0991519 ,
#         -0.09116768, -0.08318347, -0.07519925, -0.06721504, -0.05923082,
#         -0.05124661, -0.04326239, -0.03527818, -0.02729396, -0.01930974,
#         -0.01132553, -0.00334131,  0.0046429 ,  0.01262712,  0.02061133,
#          0.02859555,  0.03657976,  0.04456398,  0.05254819,  0.06053241,
#          0.06851663,  0.07650084,  0.08448506,  0.09246927,  0.10045349,
#          0.1084377 ,  0.11642192,  0.12440613,  0.13239035,  0.14037457,
#          0.14835878,  0.156343  ,  0.16432721,  0.17231143,  0.18029564,
#          0.18827986]),
#  <BarContainer object of 50 artists>)

# %%
data=torch.cat((data2, data3), 0)
data=F.adaptive_avg_pool1d(data, 512)
data=F.adaptive_avg_pool1d(t(data), 512)
data=t(data)
data=F.normalize(data)
print("Shape of spectrogram: {}".format(data.size()))
plt.figure()
plt.imshow(data, cmap='RdBu_r')
# Out:
# Shape of spectrogram: torch.Size([512, 512])

# %%
plt.hist(data.flatten(), bins=50)
# Out:
# (array([1.0000e+01, 1.5000e+01, 2.9000e+01, 4.1000e+01, 5.8000e+01,
#         1.1300e+02, 1.9700e+02, 3.3200e+02, 5.2400e+02, 8.3700e+02,
#         1.2470e+03, 1.8020e+03, 2.6360e+03, 3.7640e+03, 5.1650e+03,
#         6.8900e+03, 8.7940e+03, 1.0348e+04, 1.2151e+04, 1.2996e+04,
#         1.3862e+04, 1.4373e+04, 1.4982e+04, 1.5343e+04, 1.5471e+04,
#         1.5115e+04, 1.4861e+04, 1.4229e+04, 1.3587e+04, 1.2378e+04,
#         1.1308e+04, 1.0025e+04, 7.8210e+03, 6.3090e+03, 4.7390e+03,
#         3.3510e+03, 2.3270e+03, 1.4650e+03, 9.8300e+02, 6.5200e+02,
#         4.1000e+02, 2.3400e+02, 1.4400e+02, 8.9000e+01, 6.0000e+01,
#         2.9000e+01, 2.4000e+01, 1.4000e+01, 6.0000e+00, 4.0000e+00]),
#  array([-0.17337955, -0.16623511, -0.15909067, -0.15194623, -0.14480179,
#         -0.13765736, -0.13051292, -0.12336848, -0.11622404, -0.1090796 ,
#         -0.10193517, -0.09479073, -0.08764629, -0.08050185, -0.07335741,
#         -0.06621298, -0.05906854, -0.0519241 , -0.04477966, -0.03763522,
#         -0.03049079, -0.02334635, -0.01620191, -0.00905747, -0.00191303,
#          0.0052314 ,  0.01237584,  0.01952028,  0.02666472,  0.03380916,
#          0.0409536 ,  0.04809803,  0.05524247,  0.06238691,  0.06953135,
#          0.07667579,  0.08382022,  0.09096466,  0.0981091 ,  0.10525354,
#          0.11239798,  0.11954241,  0.12668685,  0.13383129,  0.14097573,
#          0.14812017,  0.1552646 ,  0.16240904,  0.16955348,  0.17669792,
#          0.18384236]),
#  <BarContainer object of 50 artists>)
